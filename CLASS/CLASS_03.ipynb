# %% [markdown]
# <div class="alert alert-block alert-info">
#
# #**CLASS 03 - LINEAR TEMPORAL LOGIC (LTL) - PART I**
# **Learning Objectives:**
# *   Understanding of Linear Temporal Logic (LTL)
# *   Understanding of LTL Unary Operators
# *   Implementation using LTL Unary Operators
#
# </div>

# %% [markdown]
# ## **LINEAR TEMPORAL LOGIC (LTL)**
#
# In logic, linear temporal logic or linear-time temporal logic (LTL) is a modal temporal logic with modalities referring to time. In LTL, one can encode formulae about the future of paths, e.g., a condition will eventually be true, a condition will be true until another fact becomes true, etc. It is a fragment of the more complex CTL, which additionally allows branching time and quantifiers. LTL is sometimes called propositional temporal logic, abbreviated PTL. In terms of expressive power, linear temporal logic (LTL) is a fragment of first-order logic.
#
# LTL is an extension of Propositional Logic and it can be defined in the following way:
#
# *   ¬ψ, φ ∨ ψ, φ ∧ ψ, φ -> ψ and φ <-> ψ are in LTL (PL is a subset of LTL)
# *   a set of unary operators **X**ψ (ne**X**t), **F**ψ (**F**inally) e **G**ψ (**G**lobally)
# *   a set of binary operators φ**U**ψ (**U**ntil), φ**R**ψ(**R**elease), φ**W**ψ (**W**eak until) e φ**M**ψ (Strong release).
#
# In this class, we will study the unary operators of LTL.

# %% [markdown]
# ## **UNARY LTL OPERATORS**
#
# In LTL we have three unitary operators:
#
# <table>
#   <tr>
#     <th>Operator</th>
#     <th>Meaning</th>
#   </tr>
#   <tr>
#     <td>Xψ</td>
#     <td>neXt: ψ has to hold at the next state</td>
#   </tr>
#   <tr>
#     <td>Fψ</td>
#     <td>Finally: ψ eventually has to hold (somewhere on the subsequent path)</td>
#   </tr>
#
#   <tr>
#     <td>Gψ</td>
#     <td>Globally: ψ has to hold on the entire subsequent path</td>
#     <td> </td>
#   </tr>
# </table>
#
# The graphical interpretation of these 3 operators is depicted below:
#
# ![unary.png](data:image/png;base64,...)
#
# We have several identities using these unary operators:
#
# * X (φ ∨ ψ) ≡ (X φ) ∨ (X ψ)
# * X (φ ∧ ψ) ≡ (X φ) ∧ (X ψ)
# * F (φ ∨ ψ) ≡ (F φ) ∨ (F ψ)
# * G (φ ∧ ψ) ≡ (G φ) ∧ (G ψ)
# * ¬X φ ≡ X ¬φ
# * F φ ≡ G ¬φ
# * ¬G φ ≡ F ¬φ
# * F φ ≡ F F φ
# * G φ ≡ G G φ
# * G φ ≡ φ ∧ X(G φ)
# * F φ ≡ φ ∨ X(F φ)

# %% [markdown]
# ### **EXERCISE 1**
#
# Using the module FLLOAT, prove the identity X (φ ∨ ψ) ≡ (X φ) ∨ (X ψ)

# %%
# !pip install flloat
# Out:
# Collecting flloat
#   Downloading flloat-0.3.0-py2.py3-none-any.whl (39 kB)
# Collecting lark-parser (from flloat)
#   Downloading lark_parser-0.12.0-py2.py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 4.6 MB/s eta 0:00:00
# Collecting pythomata>=0.3.2 (from flloat)
#   Downloading pythomata-0.3.2-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from flloat) (1.12)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from pythomata>=0.3.2->flloat) (0.20.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->flloat) (1.3.0)
# Installing collected packages: lark-parser, pythomata, flloat
# Successfully installed flloat-0.3.0 lark-parser-0.12.0 pythomata-0.3.2

# %%
from flloat.parser.ltlf import LTLfParser

# parse the formula
parser = LTLfParser()
formula = "F (X(fi|psi)->X(fi)|X(psi))"
parsed_formula = parser(formula)
dfa = parsed_formula.to_automaton()
graph = dfa.to_graphviz()
graph

# %%
from pickle import TRUE
test = [{"fi": False, "psi": False},
        {"fi": False, "psi": True},
        {"fi": True, "psi": False},
        {"fi": True, "psi": True}]
assert dfa.accepts(test)

# %% [markdown]
# ### **EXERCISE 2**
#
# Using the module FLLOAT, prove the following identities and test them:
#
# * X (φ ∧ ψ) ≡ (X φ) ∧ (X ψ)
# * F (φ ∨ ψ) ≡ (F φ) ∨ (F ψ)
# * G (φ ∧ ψ) ≡ (G φ) ∧ (G ψ)
# * ¬X φ ≡ X ¬φ
# * F φ ≡ G ¬φ
# * ¬G φ ≡ F ¬φ

# %%
#TYPE YOUR SOLUTIONS HERE

parser = LTLfParser()
formula = "F (X(fi&psi) -> X(fi) & X(psi))"
parsed_formula = parser(formula)
dfa = parsed_formula.to_automaton()
graph = dfa.to_graphviz()
graph

# %%
parser = LTLfParser()
formula = "F (F(fi|psi) -> F(fi) | F(psi))"
parsed_formula = parser(formula)
dfa = parsed_formula.to_automaton()
graph = dfa.to_graphviz()
graph

# %%
parser = LTLfParser()
formula = "F (G(fi&psi) -> G(fi) & G(psi))"
parsed_formula = parser(formula)
dfa = parsed_formula.to_automaton()
graph = dfa.to_graphviz()
graph

# %%
parser = LTLfParser()
formula = "F (!X(fi) <-> X(!fi))"
parsed_formula = parser(formula)
dfa = parsed_formula.to_automaton()
graph = dfa.to_graphviz()
graph

# %%
parser = LTLfParser()
formula = "F (F(fi) <-> G(!fi))"
parsed_formula = parser(formula)
dfa = parsed_formula.to_automaton()
graph = dfa.to_graphviz()
graph

#Não é uma tautologia, é necessário que hajam duas bolinhas - o que indica o estado final.
#Este estado não é capaz de reconhecer e aceitar coisas.

# %%
parser = LTLfParser()
formula = "F (F(fi) <-> !G(!fi))"
parsed_formula = parser(formula)
dfa = parsed_formula.to_automaton()
graph = dfa.to_graphviz()
graph

# %%
parser = LTLfParser()
formula = "F (!G(fi) <-> F(!fi))"
parsed_formula = parser(formula)
dfa = parsed_formula.to_automaton()
graph = dfa.to_graphviz()
graph

# %% [markdown]
# ### **HOMEWORK**
#
# Using the module FLLOAT, prove the following identities and test them:
#
# * F φ ≡ F F φ
# * G φ ≡ G G φ
# * G φ ≡ φ ∧ X(G φ)
# * F φ ≡ φ ∨ X(F φ)

# %%
parser = LTLfParser()
formula = "F (F(fi) -> F(F(fi)))"
parsed_formula = parser(formula)
dfa = parsed_formula.to_automaton()
graph = dfa.to_graphviz()
graph

# %%
parser = LTLfParser()
formula = "F (G(fi) <-> G(G(fi)))"
parsed_formula = parser(formula)
dfa = parsed_formula.to_automaton()
graph = dfa.to_graphviz()
graph

# %%
parser = LTLfParser()
formula = "F (G(fi) <-> (fi) & X(G(fi)))"
parsed_formula = parser(formula)
dfa = parsed_formula.to_automaton()
graph = dfa.to_graphviz()
graph

# %%
parser = LTLfParser()
formula = "F (F(fi) <-> (fi) | X(F(fi)))"
parsed_formula = parser(formula)
dfa = parsed_formula.to_automaton()
graph = dfa.to_graphviz()
graph
